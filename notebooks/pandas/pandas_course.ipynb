# %%
import pandas as pd

# %%
actor_names = ['Tom Cruise', 'Brad Pitt', 'Tom Hanks']

# %%
actor_names
# Out:
# ['Tom Cruise', 'Brad Pitt', 'Tom Hanks']

# %%
actor_ages = [50, 40, 60]

# %%
actor_ages
# Out:
# [50, 40, 60]
